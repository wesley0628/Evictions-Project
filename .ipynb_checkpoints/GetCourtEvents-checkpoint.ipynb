# %%
import requests
import pandas as pd
import html5lib
from lxml import html
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
from datetime import date
from datetime import datetime
import numpy as np
import matplotlib.dates as mdates
import altair as alt
import datetime as dt
 
# %matplotlib inline

# %%
all_df = pd.DataFrame(columns=["CaseNo", "S&C", "initialHearing", "firstJudgment"])
event_dict = {}
for i in range(1, 84):
    file = open("case_html/" + str(i) + "case.csv", "r")
    content = file.read()
    soup = BeautifulSoup(content, 'html5lib')
    details = soup.find("span", {"class": "caseNo"})
    if details == None:
        continue
    caseNo = details.text.strip()
    
    record = soup.find("table", {"class": "group-colored dataTable"})
    records = record.findAll('tr')
    number = len(records)
    
    dict = {"CaseNo": [],
       "Date": [],
       "Event": []}

    df = pd.DataFrame(dict)
    for i in range(0, number):
        r = records[i]
        if(r.find('td', {"class": "date"}) == None):
            continue
        date = r.find('td', {"class": "date"}).text
        event = r.findAll('td')[1].text
        if event == "Filing fee paid":
            #print("S&C" + date)
            sc = date
        elif event == "Notice of hearing":
            #print("initial hearing" + date)
            initial_hearing = date
        elif event in ["Notice of entry of judgment", "Default judgment", "Writ of restitution", "Judgment after court trial"]:
            #print("judgment" + date)
            first_judgment = date
        df.loc[len(df.index)] = [caseNo, date, event]
    
    all_df.loc[len(all_df.index)] = [caseNo, sc, initial_hearing, first_judgment]
    
#     events = df['Event'].tolist()
#     rep = set()
#     set_events = set(events)
#     if "Notice of hearing" not in set_events:
#         continue
#     for e in events:
#         if e in rep:
#             continue
#         if e in event_dict:
#             event_dict[e] += 1
#         else:
#             event_dict[e] = 1
#         rep.add(e)
all_df
# Out:
#           CaseNo         S&C initialHearing firstJudgment
# 0   2021SC000268  04-22-2021     05-11-2021    06-18-2021
# 1   2020SC001080  11-02-2020     11-17-2020    04-20-2021
# 2   2021SC000148  05-03-2021     05-03-2021    06-16-2021
# 3   2021SC000068  06-04-2021     05-03-2021    06-29-2021
# 4   2021SC001257  05-04-2021     05-03-2021    05-24-2021
# ..           ...         ...            ...           ...
# 77  2021SC000821  04-06-2021     04-22-2021    04-29-2021
# 78  2021SC000368  05-20-2021     04-22-2021    06-08-2021
# 79  2020SC003239  12-21-2020     01-04-2021    04-30-2021
# 80  2020SC001764  09-08-2020     09-16-2020    09-30-2020
# 81  2017SC000379  02-03-2017     02-14-2017    04-05-2017
#
# [82 rows x 4 columns]

# %%
df = pd.DataFrame.from_dict(event_dict, orient='index', columns=['count'])
df = df.sort_values(by="count", ascending=False)
df[df["count"] > 5]
# Out:
#                                                   count
# Notice of hearing                                    63
# Filing fee paid                                      62
# Notice of entry of judgment                          61
# Docket fee paid                                      56
# Order for financial disclosure                       55
# Declaration of nonmilitary service                   54
# Default judgment                                     49
# Case initiated by electronic filing                  41
# Writ of restitution                                  40
# Affidavit of service                                 39
# Other papers                                         37
# Summons and complaint                                35
# Return date                                          33
# Eviction return date                                 29
# Video conferencing                                   27
# Amended summons and complaint                        26
# Certificate of service                               25
# Affidavit of mailing                                 20
# Letters/correspondence                               20
# Damage hearing                                       19
# Return of unclaimed/undelivered mail service         19
# Damage list                                          17
# eFiled Document Fee Paid                             17
# Proposed Order                                       16
# Exhibit                                              15
# Order                                                14
# Return of writ                                       14
# Summons and complaint-service by sheriff             14
# Writ returned satisfied                              13
# Summons and complaint-service by private process     13
# Notes                                                12
# Receipt                                              12
# Notice of hearing returned                           11
# Notice                                               11
# Reopen                                               10
# Affidavit                                            10
# Eviction hearing                                     10
# Judgment after court trial                           10
# Case Converted to Electronic Filing                   9
# Electronic Filing Notice                              9
# Contested                                             9
# File Retained Electronically                          9
# Court trial                                           9
# Affidavit of posting                                  8
# Hearing                                               8
# Writ of restitution fee paid                          7
# Dismissed                                             7
# Answer                                                6
# Notice of retainer                                    6
# Order for dismissal                                   6
# Motion                                                6
# Prop. order for writ                                  6
# Responsible court official changed                    6
# Stipulated dismissal                                  6
# Motion to reopen                                      6

# %%
file = open("case_html/" + str(1) + "case.csv", "r")
content = file.read()
soup = BeautifulSoup(content, 'html5lib')
details = soup.find("span", {"class": "caseNo"})
caseNo = details.text.strip()
caseNo
# Out:
# '2021SC000268'

# %%
# and tag['class'] == "group-colored dataTable"
# record = soup.find(lambda tag: tag.name == 'table' and tag.has_attr('class'))

# %%
record = soup.find("table", {"class": "group-colored dataTable"})
records = record.findAll('tr')
#records = record.findAll('td', {"class": "date"})
number = len(records)

# %%
# Out:
# Empty DataFrame
# Columns: [CaseNo, S&C, initialHearing, firstJudgment]
# Index: []

# %%
# use a dataframe to strore
dict = {"CaseNo": [],
       "Date": [],
       "Event": []}

df = pd.DataFrame(dict)
for i in range(0, number):
    r = records[i]
    if(r.find('td', {"class": "date"}) == None):
        continue
    date = r.find('td', {"class": "date"}).text
    event = r.findAll('td')[1].text
    if event == "Filing fee paid":
        print("S&C" + date)
        sc = date
    elif event == "Notice of hearing":
        print("initial hearing" + date)
        initial_hearing = date
    elif event in ["Notice of entry of judgment", "Default judgment", "Writ of restitution", "Judgment after court trial"]:
        print("judgment" + date)
        first_judgment = date
    df.loc[len(df.index)] = [caseNo, date, event]
    
all_df.loc[len(all_df.index)] = [caseNo, sc, initial_hearing, first_judgment]
    
all_df
# Out:
# judgment07-27-2021
# judgment07-01-2021
# judgment06-08-2021
# initial hearing05-19-2021
# initial hearing03-29-2021
# initial hearing02-11-2021
# S&C02-09-2021
#          CaseNo         S&C initialHearing firstJudgment
# 0  2021SC002797  02-09-2021     02-11-2021    06-08-2021

# %%
date = df['Date'].tolist()
events = df['Event'].tolist()
events.reverse()

# Convert date strings (e.g. 06-30-2021) to datetime
dates = [datetime.strptime(d, "%m-%d-%Y") for d in date]
#dates.append(datetime.now())
dates.append(dates[-1])
dates.reverse()
dates
# Out:
# [datetime.datetime(2021, 4, 22, 0, 0),
#  datetime.datetime(2021, 4, 22, 0, 0),
#  datetime.datetime(2021, 4, 22, 0, 0),
#  datetime.datetime(2021, 4, 22, 0, 0),
#  datetime.datetime(2021, 4, 22, 0, 0),
#  datetime.datetime(2021, 4, 22, 0, 0),
#  datetime.datetime(2021, 4, 22, 0, 0),
#  datetime.datetime(2021, 5, 11, 0, 0),
#  datetime.datetime(2021, 5, 11, 0, 0),
#  datetime.datetime(2021, 5, 27, 0, 0),
#  datetime.datetime(2021, 5, 27, 0, 0),
#  datetime.datetime(2021, 5, 27, 0, 0),
#  datetime.datetime(2021, 5, 27, 0, 0),
#  datetime.datetime(2021, 5, 27, 0, 0),
#  datetime.datetime(2021, 6, 2, 0, 0),
#  datetime.datetime(2021, 6, 2, 0, 0),
#  datetime.datetime(2021, 6, 2, 0, 0),
#  datetime.datetime(2021, 6, 18, 0, 0),
#  datetime.datetime(2021, 6, 18, 0, 0),
#  datetime.datetime(2021, 6, 18, 0, 0),
#  datetime.datetime(2021, 6, 18, 0, 0),
#  datetime.datetime(2021, 6, 18, 0, 0),
#  datetime.datetime(2021, 6, 18, 0, 0),
#  datetime.datetime(2021, 6, 18, 0, 0),
#  datetime.datetime(2021, 6, 18, 0, 0),
#  datetime.datetime(2021, 6, 21, 0, 0),
#  datetime.datetime(2021, 6, 21, 0, 0),
#  datetime.datetime(2021, 6, 23, 0, 0),
#  datetime.datetime(2021, 7, 1, 0, 0),
#  datetime.datetime(2021, 7, 1, 0, 0),
#  datetime.datetime(2021, 7, 1, 0, 0),
#  datetime.datetime(2021, 7, 1, 0, 0),
#  datetime.datetime(2021, 7, 1, 0, 0),
#  datetime.datetime(2021, 7, 2, 0, 0),
#  datetime.datetime(2021, 7, 2, 0, 0),
#  datetime.datetime(2021, 7, 9, 0, 0),
#  datetime.datetime(2021, 8, 5, 0, 0),
#  datetime.datetime(2021, 8, 5, 0, 0),
#  datetime.datetime(2021, 8, 16, 0, 0),
#  datetime.datetime(2021, 8, 16, 0, 0),
#  datetime.datetime(2021, 8, 17, 0, 0),
#  datetime.datetime(2021, 8, 17, 0, 0),
#  datetime.datetime(2021, 8, 25, 0, 0),
#  datetime.datetime(2021, 9, 3, 0, 0),
#  datetime.datetime(2021, 9, 15, 0, 0),
#  datetime.datetime(2021, 9, 15, 0, 0),
#  datetime.datetime(2021, 9, 15, 0, 0),
#  datetime.datetime(2021, 9, 15, 0, 0),
#  datetime.datetime(2021, 9, 15, 0, 0),
#  datetime.datetime(2021, 9, 20, 0, 0),
#  datetime.datetime(2021, 9, 21, 0, 0),
#  datetime.datetime(2021, 9, 24, 0, 0),
#  datetime.datetime(2021, 9, 24, 0, 0)]

# %%
events
# Out:
# ['Summons and complaint',
#  'Case initiated by electronic filing',
#  'Filing fee paid',
#  'Declaration of nonmilitary service',
#  'Declaration of nonmilitary service',
#  'Declaration of nonmilitary service',
#  'Notice of hearing',
#  'Notes',
#  'Affidavit of service',
#  'Affidavit of service',
#  'Declaration of nonmilitary service',
#  'Declaration of nonmilitary service',
#  'Declaration of nonmilitary service',
#  'Eviction return date',
#  'Video conferencing',
#  'Notice of hearing',
#  'Eviction hearing',
#  'Writ of restitution',
#  'Filing fee paid',
#  'Filing fee paid',
#  'Notes',
#  'Other',
#  'Motion to reopen',
#  'Proposed Order',
#  'Order',
#  'Reopen',
#  'Notes',
#  'Motion hearing',
#  'Filing fee paid',
#  'Filing fee paid',
#  'Writ of restitution',
#  'Judgment after court trial',
#  'Exhibit list',
#  'Notice of entry of judgment',
#  'Writ returned satisfied',
#  'Notes',
#  'Damage list',
#  'Notice of hearing',
#  'Notes',
#  'Amended summons and complaint',
#  'Change of address notification for Eubanks, Latasha',
#  'Return of unclaimed/undelivered mail service',
#  'Affidavit of service',
#  'Return date',
#  'Default judgment',
#  'Video conferencing',
#  'Notice of entry of judgment',
#  'Order for financial disclosure',
#  'Notes',
#  'Docket fee paid',
#  'Filing fee paid',
#  'Letters/correspondence']

# %%
data = pd.DataFrame()
data['from'] = dates[:-1]
data['to'] = dates[1:] 
data['event'] = events
data
# Out:
#          from         to                                              event
# 0  2021-04-22 2021-04-22                              Summons and complaint
# 1  2021-04-22 2021-04-22                Case initiated by electronic filing
# 2  2021-04-22 2021-04-22                                    Filing fee paid
# 3  2021-04-22 2021-04-22                 Declaration of nonmilitary service
# 4  2021-04-22 2021-04-22                 Declaration of nonmilitary service
# 5  2021-04-22 2021-04-22                 Declaration of nonmilitary service
# 6  2021-04-22 2021-05-11                                  Notice of hearing
# 7  2021-05-11 2021-05-11                                              Notes
# 8  2021-05-11 2021-05-27                               Affidavit of service
# 9  2021-05-27 2021-05-27                               Affidavit of service
# 10 2021-05-27 2021-05-27                 Declaration of nonmilitary service
# 11 2021-05-27 2021-05-27                 Declaration of nonmilitary service
# 12 2021-05-27 2021-05-27                 Declaration of nonmilitary service
# 13 2021-05-27 2021-06-02                               Eviction return date
# 14 2021-06-02 2021-06-02                                 Video conferencing
# 15 2021-06-02 2021-06-02                                  Notice of hearing
# 16 2021-06-02 2021-06-18                                   Eviction hearing
# 17 2021-06-18 2021-06-18                                Writ of restitution
# 18 2021-06-18 2021-06-18                                    Filing fee paid
# 19 2021-06-18 2021-06-18                                    Filing fee paid
# 20 2021-06-18 2021-06-18                                              Notes
# 21 2021-06-18 2021-06-18                                              Other
# 22 2021-06-18 2021-06-18                                   Motion to reopen
# 23 2021-06-18 2021-06-18                                     Proposed Order
# 24 2021-06-18 2021-06-21                                              Order
# 25 2021-06-21 2021-06-21                                             Reopen
# 26 2021-06-21 2021-06-23                                              Notes
# 27 2021-06-23 2021-07-01                                     Motion hearing
# 28 2021-07-01 2021-07-01                                    Filing fee paid
# 29 2021-07-01 2021-07-01                                    Filing fee paid
# 30 2021-07-01 2021-07-01                                Writ of restitution
# 31 2021-07-01 2021-07-01                         Judgment after court trial
# 32 2021-07-01 2021-07-02                                       Exhibit list
# 33 2021-07-02 2021-07-02                        Notice of entry of judgment
# 34 2021-07-02 2021-07-09                            Writ returned satisfied
# 35 2021-07-09 2021-08-05                                              Notes
# 36 2021-08-05 2021-08-05                                        Damage list
# 37 2021-08-05 2021-08-16                                  Notice of hearing
# 38 2021-08-16 2021-08-16                                              Notes
# 39 2021-08-16 2021-08-17                      Amended summons and complaint
# 40 2021-08-17 2021-08-17  Change of address notification for Eubanks, La...
# 41 2021-08-17 2021-08-25       Return of unclaimed/undelivered mail service
# 42 2021-08-25 2021-09-03                               Affidavit of service
# 43 2021-09-03 2021-09-15                                        Return date
# 44 2021-09-15 2021-09-15                                   Default judgment
# 45 2021-09-15 2021-09-15                                 Video conferencing
# 46 2021-09-15 2021-09-15                        Notice of entry of judgment
# 47 2021-09-15 2021-09-15                     Order for financial disclosure
# 48 2021-09-15 2021-09-20                                              Notes
# 49 2021-09-20 2021-09-21                                    Docket fee paid
# 50 2021-09-21 2021-09-24                                    Filing fee paid
# 51 2021-09-24 2021-09-24                             Letters/correspondence

# %%
alt.renderers.enable('default')
#alt.renderers.enable('jupyterlab')

chart = alt.Chart(data).mark_bar().encode(
    x='from',
    x2='to',
    y='event',
    color=alt.Color('event', scale=alt.Scale(scheme='dark2'))
)

chart
# Out:
# alt.Chart(...)

# %%
def suite(num):
    file = open("more_case_html/" + str(num) + "case.csv", "r")
    content = file.read()
    soup = BeautifulSoup(content, 'html5lib')
    details = soup.find("span", {"class": "caseNo"})
    caseNo = details.text.strip()
    record = soup.find("table", {"class": "group-colored dataTable"})
    records = record.findAll('tr')
    number = len(records)
    dict = {"CaseNo": [],
       "Date": [],
       "Event": []}

    df = pd.DataFrame(dict)
    for i in range(0, number):
        r = records[i]
        if(r.find('td', {"class": "date"}) == None):
            continue
        date = r.find('td', {"class": "date"}).text
        event = r.findAll('td')[1].text
        df.loc[len(df.index)] = [caseNo, date, event]
    date = df['Date'].tolist()
    events = df['Event'].tolist()
    events.reverse()

    # Convert date strings (e.g. 06-30-2021) to datetime
    dates = [datetime.strptime(d, "%m-%d-%Y") for d in date]
    #dates.append(datetime.now())
    dates.append(dates[-1])
    dates.reverse()
    
    data = pd.DataFrame()
    data['from'] = dates[:-1]
    data['to'] = dates[1:] 
    data['event'] = events

    return data
