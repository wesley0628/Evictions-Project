# %%
import requests
import pandas as pd
import html5lib
from lxml import html
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
from datetime import date
import numpy as np
import matplotlib.dates as mdates
import altair as alt
import datetime as dt
 
# %matplotlib inline

# %%
file = open("more_case_html/" + str(1) + "case.csv", "r")
content = file.read()
soup = BeautifulSoup(content, 'html5lib')
details = soup.find(id="civilJdgmts")
caseNo = details.find("a", {"class": "case-link"})
caseNo.text
# Out:
# '2021SC015147'

# %%
# and tag['class'] == "group-colored dataTable"
# record = soup.find(lambda tag: tag.name == 'table' and tag.has_attr('class'))

# %%
record = soup.find("table", {"class": "group-colored dataTable"})
records = record.findAll('tr')
#records = record.findAll('td', {"class": "date"})
number = len(records)
#records

# %%
# use a dataframe to strore
dict = {"CaseNo": [],
       "Date": [],
       "Event": []}

df = pd.DataFrame(dict)
for i in range(0, number):
    r = records[i]
    if(r.find('td', {"class": "date"}) == None):
        continue
    date = r.find('td', {"class": "date"}).text
    event = r.findAll('td')[1].text
    df.loc[len(df.index)] = [caseNo.text, date, event]

df
# Out:
#           CaseNo        Date                                  Event
# 0   2021SC015147  11-02-2021            Notice of entry of judgment
# 1   2021SC015147  10-14-2021                       Default judgment
# 2   2021SC015147  10-14-2021                     Video conferencing
# 3   2021SC015147  10-14-2021                                Hearing
# 4   2021SC015147  10-11-2021                      Notice of hearing
# 5   2021SC015147  10-11-2021                                Exhibit
# 6   2021SC015147  10-11-2021                   Proof of publication
# 7   2021SC015147  10-11-2021                           Other papers
# 8   2021SC015147  10-11-2021                   Affidavit of mailing
# 9   2021SC015147  10-11-2021                                Exhibit
# 10  2021SC015147  10-11-2021                           Other papers
# 11  2021SC015147  09-30-2021                      Notice of hearing
# 12  2021SC015147  07-27-2021                     Video conferencing
# 13  2021SC015147  07-27-2021                            Return date
# 14  2021SC015147  07-26-2021                   Affidavit of mailing
# 15  2021SC015147  07-26-2021                 Certified mail service
# 16  2021SC015147  07-26-2021               Affidavit of non-service
# 17  2021SC015147  07-13-2021                      Notice of hearing
# 18  2021SC015147  06-30-2021                 Certified mail service
# 19  2021SC015147  06-30-2021                           Other papers
# 20  2021SC015147  06-30-2021     Declaration of nonmilitary service
# 21  2021SC015147  06-30-2021                                 Notice
# 22  2021SC015147  06-30-2021                              Affidavit
# 23  2021SC015147  06-30-2021                        Filing fee paid
# 24  2021SC015147  06-30-2021    Case initiated by electronic filing
# 25  2021SC015147  06-30-2021  Summons and Complaint - Smalls Claims

# %%
date = df['Date'].tolist()
events = df['Event'].tolist()
events.reverse()

# Convert date strings (e.g. 06-30-2021) to datetime
dates = [datetime.strptime(d, "%m-%d-%Y") for d in date]
#dates.append(datetime.now())
dates.append(dates[-1])
dates.reverse()
dates
# Out:
# [datetime.datetime(2021, 6, 30, 0, 0),
#  datetime.datetime(2021, 6, 30, 0, 0),
#  datetime.datetime(2021, 6, 30, 0, 0),
#  datetime.datetime(2021, 6, 30, 0, 0),
#  datetime.datetime(2021, 6, 30, 0, 0),
#  datetime.datetime(2021, 6, 30, 0, 0),
#  datetime.datetime(2021, 6, 30, 0, 0),
#  datetime.datetime(2021, 6, 30, 0, 0),
#  datetime.datetime(2021, 6, 30, 0, 0),
#  datetime.datetime(2021, 7, 13, 0, 0),
#  datetime.datetime(2021, 7, 26, 0, 0),
#  datetime.datetime(2021, 7, 26, 0, 0),
#  datetime.datetime(2021, 7, 26, 0, 0),
#  datetime.datetime(2021, 7, 27, 0, 0),
#  datetime.datetime(2021, 7, 27, 0, 0),
#  datetime.datetime(2021, 9, 30, 0, 0),
#  datetime.datetime(2021, 10, 11, 0, 0),
#  datetime.datetime(2021, 10, 11, 0, 0),
#  datetime.datetime(2021, 10, 11, 0, 0),
#  datetime.datetime(2021, 10, 11, 0, 0),
#  datetime.datetime(2021, 10, 11, 0, 0),
#  datetime.datetime(2021, 10, 11, 0, 0),
#  datetime.datetime(2021, 10, 11, 0, 0),
#  datetime.datetime(2021, 10, 14, 0, 0),
#  datetime.datetime(2021, 10, 14, 0, 0),
#  datetime.datetime(2021, 10, 14, 0, 0),
#  datetime.datetime(2021, 11, 2, 0, 0)]

# %%
events
# Out:
# ['Notice of entry of judgment',
#  'Default judgment',
#  'Video conferencing',
#  'Hearing',
#  'Notice of hearing',
#  'Exhibit',
#  'Proof of publication',
#  'Other papers',
#  'Affidavit of mailing',
#  'Exhibit',
#  'Other papers',
#  'Notice of hearing',
#  'Video conferencing',
#  'Return date',
#  'Affidavit of mailing',
#  'Certified mail service',
#  'Affidavit of non-service',
#  'Notice of hearing',
#  'Certified mail service',
#  'Other papers',
#  'Declaration of nonmilitary service',
#  'Notice',
#  'Affidavit',
#  'Filing fee paid',
#  'Case initiated by electronic filing',
#  'Summons and Complaint - Smalls Claims']

# %%
data = pd.DataFrame()
data['from'] = dates[:-1]
data['to'] = dates[1:] 
data['event'] = events
data
# Out:
#          from         to                                  event
# 0  2021-06-30 2021-06-30  Summons and Complaint - Smalls Claims
# 1  2021-06-30 2021-06-30    Case initiated by electronic filing
# 2  2021-06-30 2021-06-30                        Filing fee paid
# 3  2021-06-30 2021-06-30                              Affidavit
# 4  2021-06-30 2021-06-30                                 Notice
# 5  2021-06-30 2021-06-30     Declaration of nonmilitary service
# 6  2021-06-30 2021-06-30                           Other papers
# 7  2021-06-30 2021-06-30                 Certified mail service
# 8  2021-06-30 2021-07-13                      Notice of hearing
# 9  2021-07-13 2021-07-26               Affidavit of non-service
# 10 2021-07-26 2021-07-26                 Certified mail service
# 11 2021-07-26 2021-07-26                   Affidavit of mailing
# 12 2021-07-26 2021-07-27                            Return date
# 13 2021-07-27 2021-07-27                     Video conferencing
# 14 2021-07-27 2021-09-30                      Notice of hearing
# 15 2021-09-30 2021-10-11                           Other papers
# 16 2021-10-11 2021-10-11                                Exhibit
# 17 2021-10-11 2021-10-11                   Affidavit of mailing
# 18 2021-10-11 2021-10-11                           Other papers
# 19 2021-10-11 2021-10-11                   Proof of publication
# 20 2021-10-11 2021-10-11                                Exhibit
# 21 2021-10-11 2021-10-11                      Notice of hearing
# 22 2021-10-11 2021-10-14                                Hearing
# 23 2021-10-14 2021-10-14                     Video conferencing
# 24 2021-10-14 2021-10-14                       Default judgment
# 25 2021-10-14 2021-11-02            Notice of entry of judgment

# %%
alt.renderers.enable('default')
#alt.renderers.enable('jupyterlab')

chart = alt.Chart(data).mark_bar().encode(
    x='from',
    x2='to',
    y='event',
    color=alt.Color('event', scale=alt.Scale(scheme='dark2'))
)

chart
# Out:
# alt.Chart(...)
